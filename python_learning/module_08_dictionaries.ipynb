# %% [markdown]
# # Module 08: Dictionaries
#
# Understand dictionaries, their syntax, how to store and access data, and dictionary methods.

# %% [markdown]
# ## Creating Dictionaries

# %%
student = {
    "name": "Alice",
    "age": 25,
    "scores": [90, 85, 88]
}
print("Student:", student)
print("Type:", type(student))

# %% [markdown]
# ## Accessing Values

# %%
student = {"name": "Alice", "age": 25, "grade": "A"}

# Access with bracket notation
print("Name:", student["name"])

# Access with get() method
print("Age:", student.get("age"))

# Default value if key doesn't exist
print("GPA:", student.get("gpa", "N/A"))

# %% [markdown]
# ## Adding and Updating

# %%
student = {"name": "Alice", "age": 25}
print("Initial:", student)

# Add new key
student["grade"] = "A"
print("After adding grade:", student)

# Update existing key
student["age"] = 26
print("After updating age:", student)

# %% [markdown]
# ## Iterating Through Dictionaries

# %%
student = {"name": "Alice", "age": 25, "grade": "A"}

# Iterate through keys and values
for key, value in student.items():
    print(f"{key} => {value}")

print()

# Only keys
print("Keys:", list(student.keys()))

# Only values
print("Values:", list(student.values()))

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Store contact details.
#
# ### Medium
# Group product information in a catalog.
#
# ### Difficult
# Represent a JSON-like API response.
