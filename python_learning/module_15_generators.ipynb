# %% [markdown]
# # Module 15: Generators
#
# Learn how to create and use generators in Python programming.

# %% [markdown]
# ## Generator Expressions

# %%
# Generator expression (uses parentheses)
squares = (x * x for x in range(1, 6))
print("Generator object:", squares)

# Iterate through generator
for value in squares:
    print(value)

# %% [markdown]
# ## Generator Functions

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Iterate over large ranges without building a list.
#
# ### Medium
# Stream data from a file line by line.
#
# ### Difficult
# Build a pipeline of generator functions for processing events.
