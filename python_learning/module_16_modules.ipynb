# %% [markdown]
# # Module 16: Modules
#
# Understand how to create modules, import functions or variables from other modules, and learn about Python built-in modules.

# %% [markdown]
# ## Importing from Modules

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Organize helper functions in separate files.
#
# ### Medium
# Share utility modules across multiple scripts.
#
# ### Difficult
# Build a reusable package of modules for a small application.
