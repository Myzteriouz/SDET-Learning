# %% [markdown]
# # Module 14: Anonymous Functions
#
# Learn about Lambda functions and how to use them with filter, map, and reduce.

# %% [markdown]
# ## Lambda Functions

# %%
# Simple lambda
square = lambda x: x * x
print("Square of 5:", square(5))

# Lambda with multiple arguments
add = lambda x, y: x + y
print("Sum of 3 and 4:", add(3, 4))

# %% [markdown]
# ## Map Function

# %%
nums = [1, 2, 3, 4]
# Apply function to each element
squared = list(map(lambda x: x * x, nums))
print("Squared:", squared)

# %% [markdown]
# ## Filter Function

# %%
nums = [1, 2, 3, 4, 5, 6]
# Filter elements based on condition
evens = list(filter(lambda x: x % 2 == 0, nums))
print("Even numbers:", evens)

# %% [markdown]
# ## Reduce Function

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Process a list with map.
#
# ### Medium
# Filter and transform values in one pass.
#
# ### Difficult
# Use lambdas inside higher-order functions for compact logic.
