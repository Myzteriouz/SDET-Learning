# %% [markdown]
# # Module 12: List and Dictionary Comprehension
#
# Learn about list and dictionary comprehension and their syntax.

# %% [markdown]
# ## List Comprehension

# %%
# Basic list comprehension
squares = [x * x for x in range(1, 6)]
print("Squares:", squares)

# %% [markdown]
# ## List Comprehension with Condition

# %%
# Filter with if condition
evens = [x for x in range(10) if x % 2 == 0]
print("Even numbers:", evens)

# Conditional expression
result = ["even" if x % 2 == 0 else "odd" for x in range(5)]
print("Even/Odd:", result)

# %% [markdown]
# ## Dictionary Comprehension

# %%
# Create dictionary from list
names = ["Alice", "Bob", "Charlie"]
lengths = {name: len(name) for name in names}
print("Lengths:", lengths)

# Dictionary comprehension with condition
numbers = range(10)
even_squares = {x: x**2 for x in numbers if x % 2 == 0}
print("Even squares:", even_squares)

# %% [markdown]
# ## Nested Comprehension

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Create a list of squares quickly.
#
# ### Medium
# Filter and transform a list of values.
#
# ### Difficult
# Build a dictionary from two lists with conditions.
