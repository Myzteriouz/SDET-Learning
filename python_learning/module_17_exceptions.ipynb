# %% [markdown]
# # Module 17: Exceptions and Error Handling
#
# Learn about different types of errors and how to handle them using try, except, and finally blocks.

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Guard user input conversion.
#
# ### Medium
# Wrap file access or network requests.
#
# ### Difficult
# Build a retry loop with exception handling for API calls.
