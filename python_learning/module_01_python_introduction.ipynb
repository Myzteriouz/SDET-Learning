# %% [markdown]
# # Module 01: Python Introduction and Setting Up the Environment
#
# ## What you will learn
# - What Python is and why it is popular
# - Differences between Python and R
# - Common Python job roles
# - Recommended IDEs and editors
# - How to download, install, and set up Python
# - How to use virtual environments

# %% [markdown]
# ## Step-by-step Installation
#
# 1. Install Python from python.org or use Anaconda.
# 2. Choose an editor: VS Code, PyCharm, or Jupyter.
# 3. Verify installation with `python --version`.
# 4. Create and activate a virtual environment.
# 5. Install packages using `pip`.
# 6. Write and run a simple `hello.py` script.

# %%
# Example: Hello World
print("Hello, Python!")

# %% [markdown]
# ## Use Cases
#
# ### Simple
# Create a `hello.py` file and run it to make sure Python works.
#
# ### Medium
# Create a project folder with a virtual environment and install a package like `requests`.
#
# ### Difficult
# Set up a Flask project in a virtual environment and deploy it locally.
